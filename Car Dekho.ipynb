# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px

# %%
df = pd.read_csv('Car details v3.csv')

# %%
df.head(5)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.shape
# Out:
# (8128, 13)

# %%
def change(df,var):
    df[var] = df[var].str.split(' ',expand=True)
    df[var] = pd.to_numeric(df[var], errors='coerce')

# %%
change(df,'mileage')
change(df,'engine')
change(df,'max_power')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# # Data Understanding and Exploration

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['year'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(df['selling_price'], color='g', bins=100, hist_kws={'alpha': 0.4})
plt.ticklabel_format(style='plain', axis='x')
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
sns.distplot(df['km_driven'], color='g', bins=100, hist_kws={'alpha': 0.4})
plt.ticklabel_format(style='plain', axis='x')
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,6))
sns.distplot(df['seats'], color='g', bins=100, hist_kws={'alpha': 0.4})
plt.ticklabel_format(style='plain', axis='x')
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax= plt.subplots(1,2,figsize=(15,5))
sns.distplot(df['selling_price'], norm_hist=False, kde=False, ax=ax[0], color='blue')
ax[0].set_xlabel('Car Price')
ax[0].set_ylabel('Count of cars',size=12)
ax[0].set_title('Count Of Cars By Price',size=15,weight="bold")


sns.distplot(df['selling_price'], kde=True, ax=ax[1], color='green')
ax[1].set_xlabel('Car Price')
ax[1].set_ylabel('Relative Frequency of cars',size=12)
ax[1].set_title('Density or Relative Frequency Of Cars By Price',size=15,weight="bold")
plt.ticklabel_format(style='plain', axis='x')
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x='selling_price',y='year',data=df)
plt.ticklabel_format(style='plain', axis='x')

# %%
sns.scatterplot(x='selling_price',y='km_driven',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
sns.scatterplot(x='selling_price',y='mileage',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
sns.scatterplot(x='selling_price',y='engine',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
sns.scatterplot(x='selling_price',y='max_power',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
sns.scatterplot(x='engine',y='mileage',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
sns.scatterplot(x='engine',y='max_power',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(data = df, x='fuel', y='selling_price', jitter=.5)
plt.show()

# %%
f, ax = plt.subplots(figsize=(12, 6))
sns.stripplot(data = df, x='owner', y='selling_price', jitter=.5)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(data = df, x='transmission', y='selling_price', jitter=.5)
plt.show()

# %%
df_numeric = df.select_dtypes(include = ['float64', 'int64','datetime64[ns]'])
plt.style.use('bmh')
df_numeric.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
df['name'].nunique()
# Out:
# 2058

# %%
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.418783  1458.625016
# std       4.044249   8.062534e+05  5.655055e+04     4.037145   503.916303
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  7912.000000  7907.000000
# mean     91.517919     5.416719
# std      35.822499     0.959588
# min       0.000000     2.000000
# 25%      68.050000     5.000000
# 50%      82.000000     5.000000
# 75%     102.000000     5.000000
# max     400.000000    14.000000

# %%
df['torque'].nunique()
# Out:
# 441

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# torque           222
# seats            221
# dtype: int64

# %%
# df['name'] = df['name'].str.split(' ',expand=True)
df['CarCompany'] = df['name'].str.split(' ').str[0]
df['CarModel'] = df['name'].str.split(' ').str[1]

# %%
df['name'].nunique()
# Out:
# 2058

# %%
df=df.drop(['name'],axis=1)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner  mileage  engine  max_power                    torque  seats  \
# 0   First Owner    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0
# 1  Second Owner    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0
# 2   Third Owner    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0
# 3   First Owner    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0
# 4   First Owner    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0
#
#   CarCompany CarModel
# 0     Maruti    Swift
# 1      Skoda    Rapid
# 2      Honda     City
# ...

# %%
def convert_to_categorical(df,columnlist):
    for i in columnlist:
        df[i]=df[i].astype('category')
categories_columns = ['fuel','seller_type','transmission','owner','CarCompany','CarModel','torque']

convert_to_categorical(df,categories_columns)

# %%
df.groupby(["owner"]).size()
# Out:
# owner
# First Owner             5289
# Fourth & Above Owner     174
# Second Owner            2105
# Test Drive Car             5
# Third Owner              555
# dtype: int64

# %%
df.groupby(["CarCompany"]).size()
# Out:
# CarCompany
# Ambassador          4
# Ashok               1
# Audi               40
# BMW               120
# Chevrolet         230
# Daewoo              3
# Datsun             65
# Fiat               47
# Force               6
# Ford              397
# Honda             467
# Hyundai          1415
# Isuzu               5
# Jaguar             71
# Jeep               31
# Kia                 4
# Land                6
# Lexus              34
# MG                  3
# Mahindra          772
# Maruti           2448
# Mercedes-Benz      54
# Mitsubishi         14
# Nissan             81
# Opel                1
# Peugeot             1
# Renault           228
# Skoda             105
# Tata              734
# Toyota            488
# Volkswagen        186
# Volvo              67
# dtype: int64

# %%
df.groupby(["CarModel"]).size()
# Out:
# CarModel
# 3        19
# 309       1
# 5        15
# 6         6
# 7         2
#        ...
# Yeti      1
# Zen      64
# Zest     45
# i10     136
# i20     341
# Length: 207, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   category
#  4   seller_type    8128 non-null   category
#  5   transmission   8128 non-null   category
#  6   owner          8128 non-null   category
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  torque         7906 non-null   category
#  11  seats          7907 non-null   float64
#  12  CarCompany     8128 non-null   category
#  13  CarModel       8128 non-null   category
# dtypes: category(7), float64(4), int64(3)
# memory usage: 547.3 KB

# %%
df['seats'].astype('category').value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   category
#  4   seller_type    8128 non-null   category
#  5   transmission   8128 non-null   category
#  6   owner          8128 non-null   category
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  torque         7906 non-null   category
#  11  seats          7907 non-null   float64
#  12  CarCompany     8128 non-null   category
#  13  CarModel       8128 non-null   category
# dtypes: category(7), float64(4), int64(3)
# memory usage: 547.3 KB

# %%
column_1 = df["selling_price"]
column_2 = df["seats"]
correlation = column_1.corr(column_2)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner  mileage  engine  max_power                    torque  seats  \
# 0   First Owner    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0
# 1  Second Owner    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0
# 2   Third Owner    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0
# 3   First Owner    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0
# 4   First Owner    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0
#
#   CarCompany CarModel
# 0     Maruti    Swift
# 1      Skoda    Rapid
# 2      Honda     City
# ...

# %%
df['Current Year']=2021

# %%
df['no_year']=df['Current Year']-df['year']

# %%
df.drop(['year','Current Year','torque'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats CarCompany CarModel  no_year
# 0    23.40  1248.0      74.00    5.0     Maruti    Swift        7
# 1    21.14  1498.0     103.52    5.0      Skoda    Rapid        7
# 2    17.70  1497.0      78.00    5.0      Honda     City       15
# 3    23.00  1396.0      90.00    5.0    Hyundai      i20       11
# 4    16.10  1298.0      88.20    5.0     Maruti    Swift       14

# %%
df1 = df[df.isnull().any(axis=1)]

# %%
df1.head()
# Out:
#      selling_price  km_driven    fuel seller_type transmission         owner  \
# 13          200000      80000  Petrol  Individual       Manual  Second Owner
# 31           70000      50000  Petrol  Individual       Manual  Second Owner
# 78           50000      70000  Diesel  Individual       Manual   First Owner
# 87          475000      78000  Diesel      Dealer       Manual   First Owner
# 119         300000     120000  Diesel  Individual       Manual  Second Owner
#
#      mileage  engine  max_power  seats CarCompany CarModel  no_year
# 13       NaN     NaN        NaN    NaN     Maruti    Swift       14
# 31       NaN     NaN        NaN    NaN       Fiat    Palio       18
# 78       NaN     NaN        NaN    NaN       Tata   Indica       18
# 87       NaN     NaN        NaN    NaN     Maruti    Swift        6
# 119      NaN     NaN        NaN    NaN     Maruti    Swift       11

# %%
df.head(5)
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats CarCompany CarModel  no_year
# 0    23.40  1248.0      74.00    5.0     Maruti    Swift        7
# 1    21.14  1498.0     103.52    5.0      Skoda    Rapid        7
# 2    17.70  1497.0      78.00    5.0      Honda     City       15
# 3    23.00  1396.0      90.00    5.0    Hyundai      i20       11
# 4    16.10  1298.0      88.20    5.0     Maruti    Swift       14

# %%
df.isnull().sum()
# Out:
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# seats            221
# CarCompany         0
# CarModel           0
# no_year            0
# dtype: int64

# %%
# df['seats']=df['seats']==np.where(df['seats'].isna(), '5',df['seats'])

# %%
df.isnull().sum()
# Out:
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# seats            221
# CarCompany         0
# CarModel           0
# no_year            0
# dtype: int64

# %%
pd.crosstab(df['CarModel'],df['seats'])
# Out:
# seats     2.0   4.0   5.0   6.0   7.0   8.0   9.0   10.0  14.0
# CarModel
# 3            0     1    18     0     0     0     0     0     0
# 5            0     0    14     0     0     0     0     0     0
# 6            0     6     0     0     0     0     0     0     0
# 7            0     0     2     0     0     0     0     0     0
# 800          0    91     2     0     0     0     0     0     0
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yeti         0     0     1     0     0     0     0     0     0
# Zen          0     0    62     0     0     0     0     0     0
# Zest         0     0    45     0     0     0     0     0     0
# i10          0     0   136     0     0     0     0     0     0
# i20          0     0   341     0     0     0     0     0     0
#
# [197 rows x 9 columns]

# %%
# df['seats'].fillna()

# %%
car_seat = df[['CarModel','seats']].groupby('CarModel',as_index = False).apply(lambda x: x.mode())
car_seat['seats'] = round(car_seat['seats'])

# %%
car_seat=dict(zip(car_seat['CarModel'],car_seat['seats']))

# %%
car_seat
# Out:
# {'3': 5.0,
#  '309': nan,
#  '5': 5.0,
#  '6': 4.0,
#  '7': 5.0,
#  '800': 4.0,
#  'A-Star': 5.0,
#  'A3': 5.0,
#  'A4': 5.0,
#  'A6': 5.0,
#  'Accent': 5.0,
#  'Accord': 5.0,
#  'Alto': 5.0,
#  'Amaze': 5.0,
#  'Ameo': 5.0,
#  'Aria': 7.0,
#  'Aspire': 5.0,
#  'Astra': 5.0,
#  'Aveo': 5.0,
#  'Avventura': 5.0,
#  'B': 5.0,
#  'BR-V': 7.0,
#  'BRV': 7.0,
#  'Baleno': 5.0,
#  'Beat': 5.0,
#  'Bolero': 7.0,
#  'Bolt': 5.0,
#  'Brio': 5.0,
#  'CLA': 5.0,
#  'CLASSIC': 5.0,
#  'CR-V': 5.0,
#  'Camry': 5.0,
#  'Captiva': 7.0,
#  'Captur': 5.0,
#  'Celerio': 5.0,
#  'Ciaz': 5.0,
#  'City': 5.0,
#  'Civic': 5.0,
#  'Classic': 5.0,
#  'Compass': 5.0,
#  'Corolla': 5.0,
#  'Creta': 5.0,
#  'CrossPolo': 5.0,
#  'Cruze': 5.0,
#  'D-Max': 5.0,
#  'Duster': 5.0,
#  'Dzire': 5.0,
#  'E-Class': 5.0,
#  'EON': 5.0,
#  'ES': 5.0,
#  'EcoSport': 5.0,
#  'Ecosport': 5.0,
#  'Eeco': 5.0,
#  'Elantra': 5.0,
#  'Elite': 5.0,
#  'Endeavour': 7.0,
#  'Enjoy': 7.0,
#  'Ertiga': 7.0,
#  'Estate': nan,
# ...

# %%
df1['seats'] = df1['CarModel']
df1['seats'] = df1['seats'].map(car_seat)
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
car_seat = df[['CarModel','max_power']].groupby('CarModel',as_index = False).apply(lambda x: x.mode())
car_seat['max_power'] = round(car_seat['max_power'])

# %%
car_seat=dict(zip(car_seat['CarModel'],car_seat['max_power']))

# %%
df1['max_power'] = df1['CarModel']
df1['max_power'] = df1['max_power'].map(car_seat)
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
car_seat = df[['CarModel','engine']].groupby('CarModel',as_index = False).apply(lambda x: x.mode())
car_seat['engine'] = round(car_seat['engine'])
car_seat=dict(zip(car_seat['CarModel'],car_seat['engine']))
df1['engine'] = df1['CarModel']
df1['engine'] = df1['engine'].map(car_seat)
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
car_seat = df[['CarModel','mileage']].groupby('CarModel',as_index = False).apply(lambda x: x.mode())
car_seat['mileage'] = round(car_seat['mileage'])
car_seat=dict(zip(car_seat['CarModel'],car_seat['mileage']))
df1['mileage'] = df1['CarModel']
df1['mileage'] = df1['mileage'].map(car_seat)
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats CarCompany CarModel  no_year
# 0    23.40  1248.0      74.00    5.0     Maruti    Swift        7
# 1    21.14  1498.0     103.52    5.0      Skoda    Rapid        7
# 2    17.70  1497.0      78.00    5.0      Honda     City       15
# 3    23.00  1396.0      90.00    5.0    Hyundai      i20       11
# 4    16.10  1298.0      88.20    5.0     Maruti    Swift       14

# %%
df1.isna().sum()
# Out:
# selling_price     0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage          21
# engine           21
# max_power        21
# seats            21
# CarCompany        0
# CarModel          0
# no_year           0
# dtype: int64

# %%
df1.dropna(axis=0,inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.head()
# Out:
#      selling_price  km_driven    fuel seller_type transmission         owner  \
# 13          200000      80000  Petrol  Individual       Manual  Second Owner
# 78           50000      70000  Diesel  Individual       Manual   First Owner
# 87          475000      78000  Diesel      Dealer       Manual   First Owner
# 119         300000     120000  Diesel  Individual       Manual  Second Owner
# 138        2150000      27000  Diesel      Dealer    Automatic   First Owner
#
#      mileage  engine  max_power  seats CarCompany CarModel  no_year
# 13      22.0  1248.0       74.0    5.0     Maruti    Swift       14
# 78      17.0  1405.0       70.0    5.0       Tata   Indica       18
# 87      22.0  1248.0       74.0    5.0     Maruti    Swift        6
# 119     22.0  1248.0       74.0    5.0     Maruti    Swift       11
# 138     20.0  1998.0      190.0    5.0        BMW       X1        4

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (7906, 13)

# %%
df1.shape
# Out:
# (201, 13)

# %%
frames = [df, df1]

# %%
df2 = pd.concat(frames)

# %%
df2.shape
# Out:
# (8107, 13)

# %%
df2.isna().sum()
# Out:
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# seats            0
# CarCompany       0
# CarModel         0
# no_year          0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8107 entries, 0 to 8103
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  8107 non-null   int64
#  1   km_driven      8107 non-null   int64
#  2   fuel           8107 non-null   category
#  3   seller_type    8107 non-null   category
#  4   transmission   8107 non-null   category
#  5   owner          8107 non-null   category
#  6   mileage        8107 non-null   float64
#  7   engine         8107 non-null   float64
#  8   max_power      8107 non-null   float64
#  9   seats          8107 non-null   float64
#  10  CarCompany     8107 non-null   category
#  11  CarModel       8107 non-null   category
#  12  no_year        8107 non-null   int64
# dtypes: category(6), float64(4), int64(3)
# memory usage: 573.8 KB

# %%
print(df['fuel'].unique())
print(df['transmission'].unique())
print(df['seller_type'].unique())
print(df['owner'].unique())
# Out:
# ['Diesel', 'Petrol', 'LPG', 'CNG']
# Categories (4, object): ['Diesel', 'Petrol', 'LPG', 'CNG']
# ['Manual', 'Automatic']
# Categories (2, object): ['Manual', 'Automatic']
# ['Individual', 'Dealer', 'Trustmark Dealer']
# Categories (3, object): ['Individual', 'Dealer', 'Trustmark Dealer']
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth & Above Owner', 'Test Drive Car']
# Categories (5, object): ['First Owner', 'Second Owner', 'Third Owner', 'Fourth & Above Owner', 'Test Drive Car']

# %%
# drop "target" and assign it to target variable
x=df.drop(['selling_price'],axis=1)
y= df['selling_price']

# %%
# adding dummies to the dataset
x=pd.get_dummies(x,drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = .20, random_state = 42)

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

lm = linear_model.LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predicted = lm.predict(X_test)
residual = Y_test - predicted

# %%
fig = plt.figure(figsize=(15,15))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=12)
plt.title('Residual counts',fontsize=20)
plt.xlabel('Residual',fontsize=15)
plt.ylabel('Count',fontsize=15)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted',fontsize=15)
plt.ylabel('Residual',fontsize=15)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=20)

plt.show()
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
rmse = np.sqrt(mean_squared_error(Y_test, predicted))
scores = cross_val_score(regr, x, y, cv=12)

print('RMSE: ',rmse)
print('\nMean Score:')
print(scores.mean())
print('Variance score: %.2f' % r2_score(Y_test, predicted))
# Out:
# RMSE:  180975.72539394244
#
# Mean Score:
# 0.9225615241943989
# Variance score: 0.95

# %%
plt.scatter(Y_test,predicted)

# %%
A = np.array(Y_test).reshape(-1, 1)
B = predicted.reshape(-1, 1)
print(type(predicted))
print(type(Y_test))
plt.rcParams['figure.figsize'] = 16,5
plt.figure()
plt.plot(A[-100:], label="Real")
plt.plot(B[-100:], label="Predicted")
plt.legend()
plt.title("Price: real vs predicted")
plt.ylabel("price")
plt.xticks(())
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
sns.pairplot(df2, x_vars=['max_power','engine','seats','no_year','mileage','km_driven'], y_vars='selling_price', size=5, aspect=0.7, kind='reg')
# Out:
# C:\Users\ASUS\anaconda3\envs\loan\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
